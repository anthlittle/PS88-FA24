# %% [markdown]
# # PS 88 Lab 8 - Pandas, Correlation, Regression

# %% [markdown]
# ## Part 1. Tables vs. Pandas
# For the rest of the course, we'll often rely on the pandas library to manage tables. In addition to being the current industry standard for data manipulation, pandas works better with some other libraries we will use in our later work with regression and plotting. The goal of the first part of this lab is to showcase the primary differences between datascience and pandas. To start, load in both libraries:

# %%
from datascience import Table
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Let's compare how to create tables in the two libraries. The process is similar, although in pandas the syntax is somewhat different (don't worry about the details here; we will almost always just be importing tables from files).

# %%
t = Table().with_columns([
       'letter', ['a', 'b', 'c', 'z'],
       'count',  [  9,   3,   3,   1],
       'points', [  1,   2,   2,  10],
   ])
t
# Out:
# letter | count | points
# a      | 9     | 1
# b      | 3     | 2
# c      | 3     | 2
# z      | 1     | 10

# %%
pd_t = pd.DataFrame({
        'letter': ['a', 'b', 'c', 'z'],
        'count':  [  9,   3,   3,   1],
        'points': [  1,   2,   2,  10]
        })
pd_t
# Out:
#   letter  count  points
# 0      a      9       1
# 1      b      3       2
# 2      c      3       2
# 3      z      1      10

# %% [markdown]
# Let's look at some data from ProPublica about members of the Senate. The code to read a csv file is quite similar.

# %%
# datascience Table version
senator_table = Table.read_table('data/members.csv')
senator_table
# Out:
# short_title | first_name | last_name  | date_of_birth | gender | party | twitter_account | facebook_account      | dw_nominate | missed_votes_pct | votes_with_party_pct | votes_against_party_pct
# Sen.        | Lamar      | Alexander  | 1940-07-03    | M      | R     | SenAlexander    | senatorlamaralexander | 0.324       | 18.55            | 96.55                | 3.45
# Sen.        | Tammy      | Baldwin    | 1962-02-11    | F      | D     | SenatorBaldwin  | senatortammybaldwin   | -0.493      | 0.28             | 94.65                | 5.35
# Sen.        | John       | Barrasso   | 1952-07-21    | M      | R     | SenJohnBarrasso | johnbarrasso          | 0.541       | 0                | 96.91                | 3.09
# Sen.        | Michael    | Bennet     | 1964-11-28    | M      | D     | SenBennetCo     | senbennetco           | -0.227      | 17.99            | 94.91                | 5.09
# Sen.        | Marsha     | Blackburn  | 1952-06-06    | F      | R     | MarshaBlackburn | marshablackburn       | 0.619       | 1.67             | 94.01                | 5.99
# Sen.        | Richard    | Blumenthal | 1946-02-13    | M      | D     | SenBlumenthal   | SenBlumenthal         | -0.438      | 0.98             | 88.37                | 11.63
# Sen.        | Roy        | Blunt      | 1950-01-10    | M      | R     | RoyBlunt        | SenatorBlunt          | 0.426       | 2.09             | 98.28                | 1.72
# Sen.        | Cory       | Booker     | 1969-04-27    | M      | D     | SenBooker       | nan                   | -0.592      | 40.45            | 83.37                | 16.63
# Sen.        | John       | Boozman    | 1950-12-10    | M      | R     | JohnBoozman     | JohnBoozman           | 0.4         | 0                | 98.46                | 1.54
# Sen.        | Mike       | Braun      | 1954-03-24    | M      | R     | SenatorBraun    | nan                   | nan         | 0.84             | 93.21                | 6.79
# ... (92 rows omitted)

# %%
# pandas version
senator_df = pd.read_csv('data/members.csv')
senator_df
# Out:
#     short_title first_name   last_name date_of_birth gender party  \
# 0          Sen.      Lamar   Alexander    1940-07-03      M     R
# 1          Sen.      Tammy     Baldwin    1962-02-11      F     D
# 2          Sen.       John    Barrasso    1952-07-21      M     R
# 3          Sen.    Michael      Bennet    1964-11-28      M     D
# 4          Sen.     Marsha   Blackburn    1952-06-06      F     R
# ..          ...        ...         ...           ...    ...   ...
# 97         Sen.  Elizabeth      Warren    1949-06-22      F     D
# 98         Sen.    Sheldon  Whitehouse    1955-10-20      M     D
# 99         Sen.      Roger      Wicker    1951-07-05      M     R
# 100        Sen.        Ron       Wyden    1949-05-03      M     D
# 101        Sen.       Todd       Young    1972-08-24      M     R
#
#      twitter_account        facebook_account  dw_nominate  missed_votes_pct  \
# 0       SenAlexander   senatorlamaralexander        0.324             18.55
# 1     SenatorBaldwin     senatortammybaldwin       -0.493              0.28
# 2    SenJohnBarrasso            johnbarrasso        0.541              0.00
# 3        SenBennetCo             senbennetco       -0.227             17.99
# 4    MarshaBlackburn         marshablackburn        0.619              1.67
# ..               ...                     ...          ...               ...
# 97         SenWarren  senatorelizabethwarren       -0.771             39.47
# 98     SenWhitehouse       SenatorWhitehouse       -0.354              8.09
# 99     SenatorWicker           SenatorWicker        0.376              0.14
# 100         RonWyden                     NaN       -0.330              1.53
# 101     SenToddYoung        SenatorToddYoung        0.474              1.81
#
#      votes_with_party_pct  votes_against_party_pct
# 0                   96.55                     3.45
# 1                   94.65                     5.35
# 2                   96.91                     3.09
# 3                   94.91                     5.09
# 4                   94.01                     5.99
# ..                    ...                      ...
# 97                  78.67                    21.33
# 98                  93.63                     6.37
# 99                  98.73                     1.27
# 100                 85.36                    14.64
# 101                 94.99                     5.01
#
# [102 rows x 12 columns]

# %% [markdown]
# Accessing a single column has two separate methods in datascience. The first, `.column`, returns an array of the values. The second, `.select`, returns the actual column as a miniature table. Meanwhile, pandas selection returns a single list of the values.

# %%
senator_table.column('twitter_account')
# Out:
# array(['SenAlexander', 'SenatorBaldwin', 'SenJohnBarrasso', 'SenBennetCo',
#        'MarshaBlackburn', 'SenBlumenthal', 'RoyBlunt', 'SenBooker',
#        'JohnBoozman', 'SenatorBraun', 'SenSherrodBrown', 'SenatorBurr',
#        'SenatorCantwell', 'SenCapito', 'SenatorCardin', 'SenatorCarper',
#        'SenBobCasey', 'nan', 'SenatorCollins', 'ChrisCoons', 'JohnCornyn',
#        'sencortezmasto', 'SenTomCotton', 'SenKevinCramer', 'MikeCrapo',
#        'SenTedCruz', 'SteveDaines', 'SenDuckworth', 'SenatorDurbin',
#        'SenatorEnzi', 'SenJoniErnst', 'SenFeinstein', 'SenatorFischer',
#        'SenCoryGardner', 'GillibrandNY', 'GrahamBlog', 'ChuckGrassley',
#        'SenKamalaHarris', 'Senatorhassan', 'SenHawleyPress',
#        'MartinHeinrich', 'MazieHirono', 'SenJohnHoeven', 'SenHydeSmith',
#        'InhofePress', 'SenatorIsakson', 'SenRonJohnson', 'sendougjones',
#        'nan', 'SenMarkKelly', 'SenJohnKennedy', 'SenAngusKing',
#        'SenAmyKlobuchar', 'SenatorLankford', 'SenatorLeahy', 'SenMikeLee',
#        'SenatorLoeffler', 'Sen_JoeManchin', 'SenMarkey', 'McConnellPress',
#        'SenMcSallyAZ', 'SenatorMenendez', 'SenJeffMerkley', 'JerryMoran',
#        'LisaMurkowski', 'senmurphyoffice', 'PattyMurray', 'RandPaul',
#        'sendavidperdue', 'SenGaryPeters', 'SenRobPortman', 'SenJackReed',
#        'SenatorRisch', 'SenPatRoberts', 'SenatorRomney', 'SenJackyRosen',
#        'SenatorRounds', 'SenRubioPress', 'SenSanders', 'SenSasse',
#        'SenBrianSchatz', 'SenSchumer', 'SenRickScott', 'SenatorTimScott',
#        'SenatorShaheen', 'SenShelby', 'SenatorSinema', 'SenTinaSmith',
#        'SenStabenow', 'SenDanSullivan', 'SenatorTester', 'SenJohnThune',
#        'senthomtillis', 'SenToomey', 'SenatorTomUdall', 'ChrisVanHollen',
#        'MarkWarner', 'SenWarren', 'SenWhitehouse', 'SenatorWicker',
#        'RonWyden', 'SenToddYoung'],
#       dtype='<U32')

# %%
senator_table.select('twitter_account')
# Out:
# twitter_account
# SenAlexander
# SenatorBaldwin
# SenJohnBarrasso
# SenBennetCo
# MarshaBlackburn
# SenBlumenthal
# RoyBlunt
# SenBooker
# JohnBoozman
# SenatorBraun
# ... (92 rows omitted)

# %% [markdown]
# The main way to do this in pandas is to put square brackets after the name of the data frame, with the name of the variable in quotation marks.

# %%
senator_df['twitter_account']
# Out:
# 0         SenAlexander
# 1       SenatorBaldwin
# 2      SenJohnBarrasso
# 3          SenBennetCo
# 4      MarshaBlackburn
#             ...
# 97           SenWarren
# 98       SenWhitehouse
# 99       SenatorWicker
# 100           RonWyden
# 101       SenToddYoung
# Name: twitter_account, Length: 102, dtype: object

# %% [markdown]
# **Question 1.1. Write code to pull the column which indicates the party of the Senator using pandas.**

# %%
# Code for 1.1
senator_df['party']
# Out:
# 0      R
# 1      D
# 2      R
# 3      D
# 4      R
#       ..
# 97     D
# 98     D
# 99     R
# 100    D
# 101    R
# Name: party, Length: 102, dtype: object

# %% [markdown]
# If we want to access a row, datascience has the `.take()` function, and pandas has the `.loc` function (note the square brackets)

# %%
senator_table.take(0)
# Out:
# short_title | first_name | last_name | date_of_birth | gender | party | twitter_account | facebook_account      | dw_nominate | missed_votes_pct | votes_with_party_pct | votes_against_party_pct
# Sen.        | Lamar      | Alexander | 1940-07-03    | M      | R     | SenAlexander    | senatorlamaralexander | 0.324       | 18.55            | 96.55                | 3.45

# %%
senator_df.loc[0]
# Out:
# short_title                                 Sen.
# first_name                                 Lamar
# last_name                              Alexander
# date_of_birth                         1940-07-03
# gender                                         M
# party                                          R
# twitter_account                     SenAlexander
# facebook_account           senatorlamaralexander
# dw_nominate                                0.324
# missed_votes_pct                           18.55
# votes_with_party_pct                       96.55
# votes_against_party_pct                     3.45
# Name: 0, dtype: object

# %% [markdown]
# Relabeling columns is similar in both libraries, although pandas requires specifying that you're changing the columns, and has some different syntax.

# %%
senator_table.relabeled('facebook_account', 'fb')
# Out:
# short_title | first_name | last_name  | date_of_birth | gender | party | twitter_account | fb                    | dw_nominate | missed_votes_pct | votes_with_party_pct | votes_against_party_pct
# Sen.        | Lamar      | Alexander  | 1940-07-03    | M      | R     | SenAlexander    | senatorlamaralexander | 0.324       | 18.55            | 96.55                | 3.45
# Sen.        | Tammy      | Baldwin    | 1962-02-11    | F      | D     | SenatorBaldwin  | senatortammybaldwin   | -0.493      | 0.28             | 94.65                | 5.35
# Sen.        | John       | Barrasso   | 1952-07-21    | M      | R     | SenJohnBarrasso | johnbarrasso          | 0.541       | 0                | 96.91                | 3.09
# Sen.        | Michael    | Bennet     | 1964-11-28    | M      | D     | SenBennetCo     | senbennetco           | -0.227      | 17.99            | 94.91                | 5.09
# Sen.        | Marsha     | Blackburn  | 1952-06-06    | F      | R     | MarshaBlackburn | marshablackburn       | 0.619       | 1.67             | 94.01                | 5.99
# Sen.        | Richard    | Blumenthal | 1946-02-13    | M      | D     | SenBlumenthal   | SenBlumenthal         | -0.438      | 0.98             | 88.37                | 11.63
# Sen.        | Roy        | Blunt      | 1950-01-10    | M      | R     | RoyBlunt        | SenatorBlunt          | 0.426       | 2.09             | 98.28                | 1.72
# Sen.        | Cory       | Booker     | 1969-04-27    | M      | D     | SenBooker       | nan                   | -0.592      | 40.45            | 83.37                | 16.63
# Sen.        | John       | Boozman    | 1950-12-10    | M      | R     | JohnBoozman     | JohnBoozman           | 0.4         | 0                | 98.46                | 1.54
# Sen.        | Mike       | Braun      | 1954-03-24    | M      | R     | SenatorBraun    | nan                   | nan         | 0.84             | 93.21                | 6.79
# ... (92 rows omitted)

# %%
senator_df.rename(columns={"facebook_account":'fb'})
# Out:
#     short_title first_name   last_name date_of_birth gender party  \
# 0          Sen.      Lamar   Alexander    1940-07-03      M     R
# 1          Sen.      Tammy     Baldwin    1962-02-11      F     D
# 2          Sen.       John    Barrasso    1952-07-21      M     R
# 3          Sen.    Michael      Bennet    1964-11-28      M     D
# 4          Sen.     Marsha   Blackburn    1952-06-06      F     R
# ..          ...        ...         ...           ...    ...   ...
# 97         Sen.  Elizabeth      Warren    1949-06-22      F     D
# 98         Sen.    Sheldon  Whitehouse    1955-10-20      M     D
# 99         Sen.      Roger      Wicker    1951-07-05      M     R
# 100        Sen.        Ron       Wyden    1949-05-03      M     D
# 101        Sen.       Todd       Young    1972-08-24      M     R
#
#      twitter_account                      fb  dw_nominate  missed_votes_pct  \
# 0       SenAlexander   senatorlamaralexander        0.324             18.55
# 1     SenatorBaldwin     senatortammybaldwin       -0.493              0.28
# 2    SenJohnBarrasso            johnbarrasso        0.541              0.00
# 3        SenBennetCo             senbennetco       -0.227             17.99
# 4    MarshaBlackburn         marshablackburn        0.619              1.67
# ..               ...                     ...          ...               ...
# 97         SenWarren  senatorelizabethwarren       -0.771             39.47
# 98     SenWhitehouse       SenatorWhitehouse       -0.354              8.09
# 99     SenatorWicker           SenatorWicker        0.376              0.14
# 100         RonWyden                     NaN       -0.330              1.53
# 101     SenToddYoung        SenatorToddYoung        0.474              1.81
#
#      votes_with_party_pct  votes_against_party_pct
# 0                   96.55                     3.45
# 1                   94.65                     5.35
# 2                   96.91                     3.09
# 3                   94.91                     5.09
# 4                   94.01                     5.99
# ..                    ...                      ...
# 97                  78.67                    21.33
# 98                  93.63                     6.37
# 99                  98.73                     1.27
# 100                 85.36                    14.64
# 101                 94.99                     5.01
#
# [102 rows x 12 columns]

# %% [markdown]
# Creating a filtered version of the data requires the `.where` method in datascience. In pandas, it is similar to previous accessors, albeit with the condition added rather than the specific row or column value.

# %%
senator_table.where('gender', 'M')
# Out:
# short_title | first_name | last_name  | date_of_birth | gender | party | twitter_account | facebook_account      | dw_nominate | missed_votes_pct | votes_with_party_pct | votes_against_party_pct
# Sen.        | Lamar      | Alexander  | 1940-07-03    | M      | R     | SenAlexander    | senatorlamaralexander | 0.324       | 18.55            | 96.55                | 3.45
# Sen.        | John       | Barrasso   | 1952-07-21    | M      | R     | SenJohnBarrasso | johnbarrasso          | 0.541       | 0                | 96.91                | 3.09
# Sen.        | Michael    | Bennet     | 1964-11-28    | M      | D     | SenBennetCo     | senbennetco           | -0.227      | 17.99            | 94.91                | 5.09
# Sen.        | Richard    | Blumenthal | 1946-02-13    | M      | D     | SenBlumenthal   | SenBlumenthal         | -0.438      | 0.98             | 88.37                | 11.63
# Sen.        | Roy        | Blunt      | 1950-01-10    | M      | R     | RoyBlunt        | SenatorBlunt          | 0.426       | 2.09             | 98.28                | 1.72
# Sen.        | Cory       | Booker     | 1969-04-27    | M      | D     | SenBooker       | nan                   | -0.592      | 40.45            | 83.37                | 16.63
# Sen.        | John       | Boozman    | 1950-12-10    | M      | R     | JohnBoozman     | JohnBoozman           | 0.4         | 0                | 98.46                | 1.54
# Sen.        | Mike       | Braun      | 1954-03-24    | M      | R     | SenatorBraun    | nan                   | nan         | 0.84             | 93.21                | 6.79
# Sen.        | Sherrod    | Brown      | 1952-11-09    | M      | D     | SenSherrodBrown | SenatorSherrodBrown   | -0.428      | 1.67             | 91.96                | 8.04
# Sen.        | Richard    | Burr       | 1955-11-30    | M      | R     | SenatorBurr     | SenatorRichardBurr    | 0.45        | 12.27            | 98.4                 | 1.6
# ... (66 rows omitted)

# %%
senator_df[senator_df['gender'] == 'M']
# Out:
#     short_title first_name   last_name date_of_birth gender party  \
# 0          Sen.      Lamar   Alexander    1940-07-03      M     R
# 2          Sen.       John    Barrasso    1952-07-21      M     R
# 3          Sen.    Michael      Bennet    1964-11-28      M     D
# 5          Sen.    Richard  Blumenthal    1946-02-13      M     D
# 6          Sen.        Roy       Blunt    1950-01-10      M     R
# ..          ...        ...         ...           ...    ...   ...
# 96         Sen.       Mark      Warner    1954-12-15      M     D
# 98         Sen.    Sheldon  Whitehouse    1955-10-20      M     D
# 99         Sen.      Roger      Wicker    1951-07-05      M     R
# 100        Sen.        Ron       Wyden    1949-05-03      M     D
# 101        Sen.       Todd       Young    1972-08-24      M     R
#
#      twitter_account       facebook_account  dw_nominate  missed_votes_pct  \
# 0       SenAlexander  senatorlamaralexander        0.324             18.55
# 2    SenJohnBarrasso           johnbarrasso        0.541              0.00
# 3        SenBennetCo            senbennetco       -0.227             17.99
# 5      SenBlumenthal          SenBlumenthal       -0.438              0.98
# 6           RoyBlunt           SenatorBlunt        0.426              2.09
# ..               ...                    ...          ...               ...
# 96        MarkWarner            MarkRWarner       -0.201              2.79
# 98     SenWhitehouse      SenatorWhitehouse       -0.354              8.09
# 99     SenatorWicker          SenatorWicker        0.376              0.14
# 100         RonWyden                    NaN       -0.330              1.53
# 101     SenToddYoung       SenatorToddYoung        0.474              1.81
#
#      votes_with_party_pct  votes_against_party_pct
# 0                   96.55                     3.45
# 2                   96.91                     3.09
# 3                   94.91                     5.09
# 5                   88.37                    11.63
# 6                   98.28                     1.72
# ..                    ...                      ...
# 96                  93.62                     6.38
# 98                  93.63                     6.37
# 99                  98.73                     1.27
# 100                 85.36                    14.64
# 101                 94.99                     5.01
#
# [76 rows x 12 columns]

# %% [markdown]
# **Question 1.2. Write code to create separate pandas data frames for Senators who are Democrats (call this `senator_D`) and Senators who are Republicans (call this `senator_R`)**

# %%
# Code for 1.2
senator_D = senator_df[senator_df['party'] == 'D']
senator_D
# Out:
#     short_title   first_name     last_name date_of_birth gender party  \
# 1          Sen.        Tammy       Baldwin    1962-02-11      F     D
# 3          Sen.      Michael        Bennet    1964-11-28      M     D
# 5          Sen.      Richard    Blumenthal    1946-02-13      M     D
# 7          Sen.         Cory        Booker    1969-04-27      M     D
# 10         Sen.      Sherrod         Brown    1952-11-09      M     D
# 12         Sen.        Maria      Cantwell    1958-10-13      F     D
# 14         Sen.     Benjamin        Cardin    1943-10-05      M     D
# 15         Sen.       Thomas        Carper    1947-01-23      M     D
# 16         Sen.          Bob         Casey    1960-04-13      M     D
# 19         Sen.  Christopher         Coons    1963-09-09      M     D
# 21         Sen.    Catherine  Cortez Masto    1964-03-29      F     D
# 27         Sen.        Tammy     Duckworth    1968-03-12      F     D
# 28         Sen.      Richard        Durbin    1944-11-21      M     D
# 31         Sen.       Dianne     Feinstein    1933-06-22      F     D
# 34         Sen.      Kirsten    Gillibrand    1966-12-09      F     D
# 37         Sen.       Kamala        Harris    1964-10-20      F     D
# 38         Sen.     Margaret        Hassan    1958-02-27      F     D
# 40         Sen.       Martin      Heinrich    1971-10-17      M     D
# 41         Sen.        Mazie        Hirono    1947-11-03      F     D
# 47         Sen.         Doug         Jones    1954-05-04      M     D
# 48         Sen.          Tim         Kaine    1958-02-26      M     D
# 49         Sen.         Mark         Kelly    1964-02-21      M     D
# 52         Sen.          Amy     Klobuchar    1960-05-25      F     D
# 54         Sen.      Patrick         Leahy    1940-03-31      M     D
# 57         Sen.          Joe       Manchin    1947-08-24      M     D
# 58         Sen.       Edward        Markey    1946-07-11      M     D
# 61         Sen.       Robert      Menendez    1954-01-01      M     D
# 62         Sen.         Jeff       Merkley    1956-10-24      M     D
# 65         Sen.  Christopher        Murphy    1973-08-03      M     D
# 66         Sen.        Patty        Murray    1950-10-11      F     D
# 69         Sen.         Gary        Peters    1958-12-01      M     D
# 71         Sen.         Jack          Reed    1949-11-12      M     D
# 75         Sen.        Jacky         Rosen    1957-08-02      F     D
# 80         Sen.        Brian        Schatz    1972-10-20      M     D
# 81         Sen.      Charles       Schumer    1950-11-23      M     D
# 84         Sen.       Jeanne       Shaheen    1947-01-28      F     D
# 86         Sen.      Kyrsten        Sinema    1976-07-12      F     D
# 87         Sen.         Tina         Smith    1958-03-04      F     D
# 88         Sen.       Debbie      Stabenow    1950-04-29      F     D
# 90         Sen.          Jon        Tester    1956-08-21      M     D
# 94         Sen.          Tom         Udall    1948-05-18      M     D
# 95         Sen.        Chris    Van Hollen    1959-01-10      M     D
# 96         Sen.         Mark        Warner    1954-12-15      M     D
# 97         Sen.    Elizabeth        Warren    1949-06-22      F     D
# 98         Sen.      Sheldon    Whitehouse    1955-10-20      M     D
# 100        Sen.          Ron         Wyden    1949-05-03      M     D
#
#      twitter_account        facebook_account  dw_nominate  missed_votes_pct  \
# 1     SenatorBaldwin     senatortammybaldwin       -0.493              0.28
# 3        SenBennetCo             senbennetco       -0.227             17.99
# 5      SenBlumenthal           SenBlumenthal       -0.438              0.98
# 7          SenBooker                     NaN       -0.592             40.45
# 10   SenSherrodBrown     SenatorSherrodBrown       -0.428              1.67
# 12   SenatorCantwell         senatorcantwell       -0.304              1.12
# 14     SenatorCardin        senatorbencardin       -0.320              2.09
# 15     SenatorCarper               tomcarper       -0.176              0.56
# 16       SenBobCasey         SenatorBobCasey       -0.315              0.00
# 19        ChrisCoons       senatorchriscoons       -0.229              3.49
# 21    sencortezmasto      SenatorCortezMasto       -0.371              0.56
# 27      SenDuckworth            SenDuckworth       -0.337              3.07
# 28     SenatorDurbin           SenatorDurbin       -0.348              1.53
# 31      SenFeinstein        senatorfeinstein       -0.267              1.26
# 34      GillibrandNY    SenKirstenGillibrand       -0.475             15.34
# 37   SenKamalaHarris     SenatorKamalaHarris       -0.709             55.23
# 38     Senatorhassan           SenatorHassan       -0.233              0.14
# 40    MartinHeinrich          MartinHeinrich       -0.328              3.63
# 41       MazieHirono           senatorhirono       -0.512              2.65
# 47      sendougjones        senatordougjones       -0.088              4.88
# 48               NaN            SenatorKaine       -0.243              2.37
# 49      SenMarkKelly            SenMarkKelly          NaN              0.00
# 52   SenAmyKlobuchar                     NaN       -0.284             29.01
# 54      SenatorLeahy     SenatorPatrickLeahy       -0.359              3.21
# 57    Sen_JoeManchin           JoeManchinIII       -0.056              1.95
# 58         SenMarkey               EdJMarkey       -0.512             10.88
# 61   SenatorMenendez         senatormenendez       -0.366              0.70
# 62    SenJeffMerkley             jeffmerkley       -0.442              0.70
# 65   senmurphyoffice           chrismurphyct       -0.269              0.56
# 66       PattyMurray                     NaN       -0.352              5.44
# 69     SenGaryPeters           SenGaryPeters       -0.246              0.14
# 71       SenJackReed             SenJackReed       -0.367              0.42
# 75     SenJackyRosen           RepJackyRosen       -0.286              0.56
# 80    SenBrianSchatz          SenBrianSchatz       -0.443              5.02
# 81        SenSchumer              senschumer       -0.359              0.00
# 84    SenatorShaheen          SenatorShaheen       -0.238              0.98
# 86     SenatorSinema     CongresswomanSinema       -0.101              8.37
# 87      SenTinaSmith          USSenTinaSmith       -0.396              0.84
# 88       SenStabenow         SenatorStabenow       -0.343              4.88
# 90     SenatorTester           senatortester       -0.216              3.07
# 94   SenatorTomUdall         senatortomudall       -0.453              1.82
# 95    ChrisVanHollen          chrisvanhollen       -0.392              0.14
# 96        MarkWarner             MarkRWarner       -0.201              2.79
# 97         SenWarren  senatorelizabethwarren       -0.771             39.47
# 98     SenWhitehouse       SenatorWhitehouse       -0.354              8.09
# 100         RonWyden                     NaN       -0.330              1.53
#
#      votes_with_party_pct  votes_against_party_pct
# 1                   94.65                     5.35
# 3                   94.91                     5.09
# 5                   88.37                    11.63
# 7                   83.37                    16.63
# 10                  91.96                     8.04
# 12                  90.58                     9.42
# 14                  95.15                     4.85
# 15                  90.13                     9.87
# 16                  95.38                     4.62
# 19                  94.47                     5.53
# 21                  95.94                     4.06
# 27                  94.95                     5.05
# 28                  95.47                     4.53
# 31                  95.61                     4.39
# 34                  76.40                    23.60
# 37                  76.85                    23.15
# 38                  91.62                     8.38
# 40                  93.75                     6.25
# 41                  83.11                    16.89
# 47                  78.76                    21.24
# 48                  94.98                     5.02
# 49                  65.12                    34.88
# 52                  86.00                    14.00
# 54                  94.21                     5.79
# 57                  74.37                    25.63
# 58                  74.80                    25.20
# 61                  92.17                     7.83
# 62                  83.31                    16.69
# 65                  88.84                    11.16
# 66                  90.74                     9.26
# 69                  95.24                     4.76
# 71                  94.93                     5.07
# 75                  95.21                     4.79
# 80                  88.52                    11.48
# 81                  87.73                    12.27
# 84                  92.44                     7.56
# 86                  77.08                    22.92
# 87                  93.89                     6.11
# 88                  93.04                     6.96
# 90                  92.47                     7.53
# 94                  93.53                     6.47
# 95                  91.04                     8.96
# 96                  93.62                     6.38
# 97                  78.67                    21.33
# 98                  93.63                     6.37
# 100                 85.36                    14.64

# %%
senator_R = senator_df[senator_df['party'] == 'R']
senator_R
# Out:
#     short_title first_name   last_name date_of_birth gender party  \
# 0          Sen.      Lamar   Alexander    1940-07-03      M     R
# 2          Sen.       John    Barrasso    1952-07-21      M     R
# 4          Sen.     Marsha   Blackburn    1952-06-06      F     R
# 6          Sen.        Roy       Blunt    1950-01-10      M     R
# 8          Sen.       John     Boozman    1950-12-10      M     R
# 9          Sen.       Mike       Braun    1954-03-24      M     R
# 11         Sen.    Richard        Burr    1955-11-30      M     R
# 13         Sen.    Shelley      Capito    1953-11-26      F     R
# 17         Sen.       Bill     Cassidy    1957-09-28      M     R
# 18         Sen.      Susan     Collins    1952-12-07      F     R
# 20         Sen.       John      Cornyn    1952-02-02      M     R
# 22         Sen.        Tom      Cotton    1977-05-13      M     R
# 23         Sen.      Kevin      Cramer    1961-01-21      M     R
# 24         Sen.    Michael       Crapo    1951-05-20      M     R
# 25         Sen.        Ted        Cruz    1970-12-22      M     R
# 26         Sen.      Steve      Daines    1962-08-20      M     R
# 29         Sen.    Michael        Enzi    1944-02-01      M     R
# 30         Sen.       Joni       Ernst    1970-07-01      F     R
# 32         Sen.        Deb     Fischer    1951-03-01      F     R
# 33         Sen.       Cory     Gardner    1974-08-22      M     R
# 35         Sen.    Lindsey      Graham    1955-07-09      M     R
# 36         Sen.    Charles    Grassley    1933-09-17      M     R
# 39         Sen.     Joshua      Hawley    1979-12-31      M     R
# 42         Sen.       John      Hoeven    1957-03-13      M     R
# 43         Sen.      Cindy  Hyde-Smith    1959-05-10      F     R
# 44         Sen.      James      Inhofe    1934-11-17      M     R
# 45         Sen.     Johnny     Isakson    1944-12-28      M     R
# 46         Sen.        Ron     Johnson    1955-04-08      M     R
# 50         Sen.       John     Kennedy    1951-11-21      M     R
# 53         Sen.      James    Lankford    1968-03-04      M     R
# 55         Sen.       Mike         Lee    1971-06-04      M     R
# 56         Sen.      Kelly    Loeffler    1970-11-27      F     R
# 59         Sen.      Mitch   McConnell    1942-02-20      M     R
# 60         Sen.     Martha     McSally    1966-03-22      F     R
# 63         Sen.      Jerry       Moran    1954-05-29      M     R
# 64         Sen.       Lisa   Murkowski    1957-05-22      F     R
# 67         Sen.       Rand        Paul    1963-01-07      M     R
# 68         Sen.      David      Perdue    1949-12-10      M     R
# 70         Sen.        Rob     Portman    1955-12-19      M     R
# 72         Sen.        Jim       Risch    1943-05-03      M     R
# 73         Sen.        Pat     Roberts    1936-04-20      M     R
# 74         Sen.       Mitt      Romney    1947-03-12      M     R
# 76         Sen.       Mike      Rounds    1954-10-24      M     R
# 77         Sen.      Marco       Rubio    1971-05-28      M     R
# 79         Sen.        Ben       Sasse    1972-02-22      M     R
# 82         Sen.       Rick       Scott    1952-12-01      M     R
# 83         Sen.        Tim       Scott    1965-09-19      M     R
# 85         Sen.    Richard      Shelby    1934-05-06      M     R
# 89         Sen.        Dan    Sullivan    1964-11-13      M     R
# 91         Sen.       John       Thune    1961-01-07      M     R
# 92         Sen.       Thom      Tillis    1960-08-30      M     R
# 93         Sen.    Patrick      Toomey    1961-11-17      M     R
# 99         Sen.      Roger      Wicker    1951-07-05      M     R
# 101        Sen.       Todd       Young    1972-08-24      M     R
#
#      twitter_account        facebook_account  dw_nominate  missed_votes_pct  \
# 0       SenAlexander   senatorlamaralexander        0.324             18.55
# 2    SenJohnBarrasso            johnbarrasso        0.541              0.00
# 4    MarshaBlackburn         marshablackburn        0.619              1.67
# 6           RoyBlunt            SenatorBlunt        0.426              2.09
# 8        JohnBoozman             JohnBoozman        0.400              0.00
# 9       SenatorBraun                     NaN          NaN              0.84
# 11       SenatorBurr      SenatorRichardBurr        0.450             12.27
# 13         SenCapito              senshelley        0.263              5.44
# 17               NaN                     NaN        0.456              6.42
# 18    SenatorCollins            susancollins        0.114              0.00
# 20        JohnCornyn          sen.johncornyn        0.492              0.98
# 22      SenTomCotton        SenatorTomCotton        0.573              0.70
# 23    SenKevinCramer  CongressmanKevinCramer        0.388              2.65
# 24         MikeCrapo               mikecrapo        0.511              0.56
# 25        SenTedCruz          SenatorTedCruz        0.826              5.16
# 26       SteveDaines           SteveDainesMT        0.551              1.53
# 29       SenatorEnzi                mikeenzi        0.545              4.20
# 30      SenJoniErnst            senjoniernst        0.527              1.67
# 32    SenatorFischer       senatordebfischer        0.471              3.49
# 33    SenCoryGardner          SenCoryGardner        0.444              2.09
# 35        GrahamBlog  USSenatorLindseyGraham        0.405              4.04
# 36     ChuckGrassley                grassley        0.346              1.39
# 39    SenHawleyPress                     NaN          NaN              0.56
# 42     SenJohnHoeven       SenatorJohnHoeven        0.343              1.53
# 43      SenHydeSmith                     NaN        0.374              1.67
# 44       InhofePress               jiminhofe        0.555              2.93
# 45    SenatorIsakson                     NaN        0.402             33.49
# 46     SenRonJohnson           senronjohnson        0.607              3.91
# 50    SenJohnKennedy    JohnKennedyLouisiana        0.594              2.09
# 53   SenatorLankford         SenatorLankford        0.589              0.00
# 55        SenMikeLee          senatormikelee        0.917              1.67
# 56   SenatorLoeffler                     NaN          NaN             17.59
# 59    McConnellPress          mitchmcconnell        0.401              0.00
# 60      SenMcSallyAZ        SenMarthaMcSally        0.345              3.12
# 63        JerryMoran              jerrymoran        0.415             10.32
# 64     LisaMurkowski        SenLisaMurkowski        0.212              6.83
# 67          RandPaul         SenatorRandPaul        0.876              9.34
# 68    sendavidperdue      SenatorDavidPerdue        0.562             11.58
# 70     SenRobPortman           senrobportman        0.373              1.26
# 72      SenatorRisch         senatorjimrisch        0.628              2.51
# 73     SenPatRoberts           SenPatRoberts        0.413              5.03
# 74     SenatorRomney                     NaN          NaN              0.84
# 76     SenatorRounds       SenatorMikeRounds        0.408             12.55
# 77     SenRubioPress       SenatorMarcoRubio        0.567              5.02
# 79          SenSasse            SenatorSasse        0.788              3.07
# 82      SenRickScott                     NaN          NaN              3.63
# 83   SenatorTimScott         SenatorTimScott        0.636              0.84
# 85         SenShelby           RichardShelby        0.429              0.70
# 89    SenDanSullivan          SenDanSullivan        0.485              2.79
# 91      SenJohnThune                     NaN        0.411              0.42
# 92     senthomtillis       SenatorThomTillis        0.426              5.16
# 93         SenToomey           senatortoomey        0.647              4.32
# 99     SenatorWicker           SenatorWicker        0.376              0.14
# 101     SenToddYoung        SenatorToddYoung        0.474              1.81
#
#      votes_with_party_pct  votes_against_party_pct
# 0                   96.55                     3.45
# 2                   96.91                     3.09
# 4                   94.01                     5.99
# 6                   98.28                     1.72
# 8                   98.46                     1.54
# 9                   93.21                     6.79
# 11                  98.40                     1.60
# 13                  98.52                     1.48
# 17                  97.00                     3.00
# 18                  88.62                    11.38
# 20                  98.02                     1.98
# 22                  97.17                     2.83
# 23                  99.28                     0.72
# 24                  97.60                     2.40
# 25                  92.30                     7.70
# 26                  94.72                     5.28
# 29                  96.03                     3.97
# 30                  97.00                     3.00
# 32                  98.25                     1.75
# 33                  96.84                     3.16
# 35                  97.51                     2.49
# 36                  98.01                     1.99
# 39                  94.35                     5.65
# 42                  99.00                     1.00
# 43                  98.29                     1.71
# 44                  96.39                     3.61
# 45                  98.59                     1.41
# 46                  96.35                     3.65
# 50                  93.69                     6.31
# 53                  95.79                     4.21
# 55                  84.71                    15.29
# 56                  97.47                     2.53
# 59                  97.47                     2.53
# 60                  97.69                     2.31
# 63                  94.54                     5.46
# 64                  93.82                     6.18
# 67                  80.16                    19.84
# 68                  98.25                     1.75
# 70                  98.15                     1.85
# 72                  96.83                     3.17
# 73                  98.52                     1.48
# 74                  95.47                     4.53
# 76                  97.59                     2.41
# 77                  97.04                     2.96
# 79                  94.79                     5.21
# 82                  96.21                     3.79
# 83                  97.17                     2.83
# 85                  97.32                     2.68
# 89                  96.82                     3.18
# 91                  99.01                     0.99
# 92                  97.78                     2.22
# 93                  93.84                     6.16
# 99                  98.73                     1.27
# 101                 94.99                     5.01

# %% [markdown]
# We can select rows using any logical expression which will return either True or False. For example, to select those who voted with their party more than 98 percent of the time.

# %%
senator_table.where(senator_table.column('votes_with_party_pct') > 98)
# Out:
# short_title | first_name | last_name  | date_of_birth | gender | party | twitter_account | facebook_account       | dw_nominate | missed_votes_pct | votes_with_party_pct | votes_against_party_pct
# Sen.        | Roy        | Blunt      | 1950-01-10    | M      | R     | RoyBlunt        | SenatorBlunt           | 0.426       | 2.09             | 98.28                | 1.72
# Sen.        | John       | Boozman    | 1950-12-10    | M      | R     | JohnBoozman     | JohnBoozman            | 0.4         | 0                | 98.46                | 1.54
# Sen.        | Richard    | Burr       | 1955-11-30    | M      | R     | SenatorBurr     | SenatorRichardBurr     | 0.45        | 12.27            | 98.4                 | 1.6
# Sen.        | Shelley    | Capito     | 1953-11-26    | F      | R     | SenCapito       | senshelley             | 0.263       | 5.44             | 98.52                | 1.48
# Sen.        | John       | Cornyn     | 1952-02-02    | M      | R     | JohnCornyn      | sen.johncornyn         | 0.492       | 0.98             | 98.02                | 1.98
# Sen.        | Kevin      | Cramer     | 1961-01-21    | M      | R     | SenKevinCramer  | CongressmanKevinCramer | 0.388       | 2.65             | 99.28                | 0.72
# Sen.        | Deb        | Fischer    | 1951-03-01    | F      | R     | SenatorFischer  | senatordebfischer      | 0.471       | 3.49             | 98.25                | 1.75
# Sen.        | Charles    | Grassley   | 1933-09-17    | M      | R     | ChuckGrassley   | grassley               | 0.346       | 1.39             | 98.01                | 1.99
# Sen.        | John       | Hoeven     | 1957-03-13    | M      | R     | SenJohnHoeven   | SenatorJohnHoeven      | 0.343       | 1.53             | 99                   | 1
# Sen.        | Cindy      | Hyde-Smith | 1959-05-10    | F      | R     | SenHydeSmith    | nan                    | 0.374       | 1.67             | 98.29                | 1.71
# ... (6 rows omitted)

# %%
senator_df[senator_df['votes_with_party_pct'] > 98]
# Out:
#    short_title first_name   last_name date_of_birth gender party  \
# 6         Sen.        Roy       Blunt    1950-01-10      M     R
# 8         Sen.       John     Boozman    1950-12-10      M     R
# 11        Sen.    Richard        Burr    1955-11-30      M     R
# 13        Sen.    Shelley      Capito    1953-11-26      F     R
# 20        Sen.       John      Cornyn    1952-02-02      M     R
# 23        Sen.      Kevin      Cramer    1961-01-21      M     R
# 32        Sen.        Deb     Fischer    1951-03-01      F     R
# 36        Sen.    Charles    Grassley    1933-09-17      M     R
# 42        Sen.       John      Hoeven    1957-03-13      M     R
# 43        Sen.      Cindy  Hyde-Smith    1959-05-10      F     R
# 45        Sen.     Johnny     Isakson    1944-12-28      M     R
# 68        Sen.      David      Perdue    1949-12-10      M     R
# 70        Sen.        Rob     Portman    1955-12-19      M     R
# 73        Sen.        Pat     Roberts    1936-04-20      M     R
# 91        Sen.       John       Thune    1961-01-07      M     R
# 99        Sen.      Roger      Wicker    1951-07-05      M     R
#
#    twitter_account        facebook_account  dw_nominate  missed_votes_pct  \
# 6         RoyBlunt            SenatorBlunt        0.426              2.09
# 8      JohnBoozman             JohnBoozman        0.400              0.00
# 11     SenatorBurr      SenatorRichardBurr        0.450             12.27
# 13       SenCapito              senshelley        0.263              5.44
# 20      JohnCornyn          sen.johncornyn        0.492              0.98
# 23  SenKevinCramer  CongressmanKevinCramer        0.388              2.65
# 32  SenatorFischer       senatordebfischer        0.471              3.49
# 36   ChuckGrassley                grassley        0.346              1.39
# 42   SenJohnHoeven       SenatorJohnHoeven        0.343              1.53
# 43    SenHydeSmith                     NaN        0.374              1.67
# 45  SenatorIsakson                     NaN        0.402             33.49
# 68  sendavidperdue      SenatorDavidPerdue        0.562             11.58
# 70   SenRobPortman           senrobportman        0.373              1.26
# 73   SenPatRoberts           SenPatRoberts        0.413              5.03
# 91    SenJohnThune                     NaN        0.411              0.42
# 99   SenatorWicker           SenatorWicker        0.376              0.14
#
#     votes_with_party_pct  votes_against_party_pct
# 6                  98.28                     1.72
# 8                  98.46                     1.54
# 11                 98.40                     1.60
# 13                 98.52                     1.48
# 20                 98.02                     1.98
# 23                 99.28                     0.72
# 32                 98.25                     1.75
# 36                 98.01                     1.99
# 42                 99.00                     1.00
# 43                 98.29                     1.71
# 45                 98.59                     1.41
# 68                 98.25                     1.75
# 70                 98.15                     1.85
# 73                 98.52                     1.48
# 91                 99.01                     0.99
# 99                 98.73                     1.27

# %% [markdown]
# To sort a datascience table, use the column you wish to sort by and the optional `descending` value. The only difference between the two libraries is that datascience uses `descending` while pandas uses `ascending` to differentiate sorting methods.

# %%
senator_table.sort('votes_with_party_pct')
# Out:
# short_title | first_name | last_name  | date_of_birth | gender | party | twitter_account | facebook_account       | dw_nominate | missed_votes_pct | votes_with_party_pct | votes_against_party_pct
# Sen.        | Mark       | Kelly      | 1964-02-21    | M      | D     | SenMarkKelly    | SenMarkKelly           | nan         | 0                | 65.12                | 34.88
# Sen.        | Joe        | Manchin    | 1947-08-24    | M      | D     | Sen_JoeManchin  | JoeManchinIII          | -0.056      | 1.95             | 74.37                | 25.63
# Sen.        | Edward     | Markey     | 1946-07-11    | M      | D     | SenMarkey       | EdJMarkey              | -0.512      | 10.88            | 74.8                 | 25.2
# Sen.        | Kirsten    | Gillibrand | 1966-12-09    | F      | D     | GillibrandNY    | SenKirstenGillibrand   | -0.475      | 15.34            | 76.4                 | 23.6
# Sen.        | Kamala     | Harris     | 1964-10-20    | F      | D     | SenKamalaHarris | SenatorKamalaHarris    | -0.709      | 55.23            | 76.85                | 23.15
# Sen.        | Kyrsten    | Sinema     | 1976-07-12    | F      | D     | SenatorSinema   | CongresswomanSinema    | -0.101      | 8.37             | 77.08                | 22.92
# Sen.        | Elizabeth  | Warren     | 1949-06-22    | F      | D     | SenWarren       | senatorelizabethwarren | -0.771      | 39.47            | 78.67                | 21.33
# Sen.        | Doug       | Jones      | 1954-05-04    | M      | D     | sendougjones    | senatordougjones       | -0.088      | 4.88             | 78.76                | 21.24
# Sen.        | Rand       | Paul       | 1963-01-07    | M      | R     | RandPaul        | SenatorRandPaul        | 0.876       | 9.34             | 80.16                | 19.84
# Sen.        | Bernard    | Sanders    | 1941-09-08    | M      | ID    | SenSanders      | senatorsanders         | -0.529      | 57.32            | 80.73                | 19.27
# ... (92 rows omitted)

# %%
senator_table.sort('votes_with_party_pct', descending=True)
# Out:
# short_title | first_name | last_name  | date_of_birth | gender | party | twitter_account | facebook_account       | dw_nominate | missed_votes_pct | votes_with_party_pct | votes_against_party_pct
# Sen.        | Kevin      | Cramer     | 1961-01-21    | M      | R     | SenKevinCramer  | CongressmanKevinCramer | 0.388       | 2.65             | 99.28                | 0.72
# Sen.        | John       | Thune      | 1961-01-07    | M      | R     | SenJohnThune    | nan                    | 0.411       | 0.42             | 99.01                | 0.99
# Sen.        | John       | Hoeven     | 1957-03-13    | M      | R     | SenJohnHoeven   | SenatorJohnHoeven      | 0.343       | 1.53             | 99                   | 1
# Sen.        | Roger      | Wicker     | 1951-07-05    | M      | R     | SenatorWicker   | SenatorWicker          | 0.376       | 0.14             | 98.73                | 1.27
# Sen.        | Johnny     | Isakson    | 1944-12-28    | M      | R     | SenatorIsakson  | nan                    | 0.402       | 33.49            | 98.59                | 1.41
# Sen.        | Shelley    | Capito     | 1953-11-26    | F      | R     | SenCapito       | senshelley             | 0.263       | 5.44             | 98.52                | 1.48
# Sen.        | Pat        | Roberts    | 1936-04-20    | M      | R     | SenPatRoberts   | SenPatRoberts          | 0.413       | 5.03             | 98.52                | 1.48
# Sen.        | John       | Boozman    | 1950-12-10    | M      | R     | JohnBoozman     | JohnBoozman            | 0.4         | 0                | 98.46                | 1.54
# Sen.        | Richard    | Burr       | 1955-11-30    | M      | R     | SenatorBurr     | SenatorRichardBurr     | 0.45        | 12.27            | 98.4                 | 1.6
# Sen.        | Cindy      | Hyde-Smith | 1959-05-10    | F      | R     | SenHydeSmith    | nan                    | 0.374       | 1.67             | 98.29                | 1.71
# ... (92 rows omitted)

# %%
senator_df.sort_values('votes_with_party_pct')
# Out:
#    short_title first_name   last_name date_of_birth gender party  \
# 49        Sen.       Mark       Kelly    1964-02-21      M     D
# 57        Sen.        Joe     Manchin    1947-08-24      M     D
# 58        Sen.     Edward      Markey    1946-07-11      M     D
# 34        Sen.    Kirsten  Gillibrand    1966-12-09      F     D
# 37        Sen.     Kamala      Harris    1964-10-20      F     D
# ..         ...        ...         ...           ...    ...   ...
# 45        Sen.     Johnny     Isakson    1944-12-28      M     R
# 99        Sen.      Roger      Wicker    1951-07-05      M     R
# 42        Sen.       John      Hoeven    1957-03-13      M     R
# 91        Sen.       John       Thune    1961-01-07      M     R
# 23        Sen.      Kevin      Cramer    1961-01-21      M     R
#
#     twitter_account        facebook_account  dw_nominate  missed_votes_pct  \
# 49     SenMarkKelly            SenMarkKelly          NaN              0.00
# 57   Sen_JoeManchin           JoeManchinIII       -0.056              1.95
# 58        SenMarkey               EdJMarkey       -0.512             10.88
# 34     GillibrandNY    SenKirstenGillibrand       -0.475             15.34
# 37  SenKamalaHarris     SenatorKamalaHarris       -0.709             55.23
# ..              ...                     ...          ...               ...
# 45   SenatorIsakson                     NaN        0.402             33.49
# 99    SenatorWicker           SenatorWicker        0.376              0.14
# 42    SenJohnHoeven       SenatorJohnHoeven        0.343              1.53
# 91     SenJohnThune                     NaN        0.411              0.42
# 23   SenKevinCramer  CongressmanKevinCramer        0.388              2.65
#
#     votes_with_party_pct  votes_against_party_pct
# 49                 65.12                    34.88
# 57                 74.37                    25.63
# 58                 74.80                    25.20
# 34                 76.40                    23.60
# 37                 76.85                    23.15
# ..                   ...                      ...
# 45                 98.59                     1.41
# 99                 98.73                     1.27
# 42                 99.00                     1.00
# 91                 99.01                     0.99
# 23                 99.28                     0.72
#
# [102 rows x 12 columns]

# %%
senator_df.sort_values('votes_with_party_pct', ascending=False)
# Out:
#    short_title first_name   last_name date_of_birth gender party  \
# 23        Sen.      Kevin      Cramer    1961-01-21      M     R
# 91        Sen.       John       Thune    1961-01-07      M     R
# 42        Sen.       John      Hoeven    1957-03-13      M     R
# 99        Sen.      Roger      Wicker    1951-07-05      M     R
# 45        Sen.     Johnny     Isakson    1944-12-28      M     R
# ..         ...        ...         ...           ...    ...   ...
# 37        Sen.     Kamala      Harris    1964-10-20      F     D
# 34        Sen.    Kirsten  Gillibrand    1966-12-09      F     D
# 58        Sen.     Edward      Markey    1946-07-11      M     D
# 57        Sen.        Joe     Manchin    1947-08-24      M     D
# 49        Sen.       Mark       Kelly    1964-02-21      M     D
#
#     twitter_account        facebook_account  dw_nominate  missed_votes_pct  \
# 23   SenKevinCramer  CongressmanKevinCramer        0.388              2.65
# 91     SenJohnThune                     NaN        0.411              0.42
# 42    SenJohnHoeven       SenatorJohnHoeven        0.343              1.53
# 99    SenatorWicker           SenatorWicker        0.376              0.14
# 45   SenatorIsakson                     NaN        0.402             33.49
# ..              ...                     ...          ...               ...
# 37  SenKamalaHarris     SenatorKamalaHarris       -0.709             55.23
# 34     GillibrandNY    SenKirstenGillibrand       -0.475             15.34
# 58        SenMarkey               EdJMarkey       -0.512             10.88
# 57   Sen_JoeManchin           JoeManchinIII       -0.056              1.95
# 49     SenMarkKelly            SenMarkKelly          NaN              0.00
#
#     votes_with_party_pct  votes_against_party_pct
# 23                 99.28                     0.72
# 91                 99.01                     0.99
# 42                 99.00                     1.00
# 99                 98.73                     1.27
# 45                 98.59                     1.41
# ..                   ...                      ...
# 37                 76.85                    23.15
# 34                 76.40                    23.60
# 58                 74.80                    25.20
# 57                 74.37                    25.63
# 49                 65.12                    34.88
#
# [102 rows x 12 columns]

# %% [markdown]
# We can plot a histogram of a column in the datascience table fairly easily:

# %%
senator_table.hist('votes_with_party_pct')

# %% [markdown]
# With pandas, the easiest method is to select the specifc column, and then call the `hist` function.

# %%
senator_df['votes_with_party_pct'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Question 1.3. Using pandas, create separate histograms of the `votes_with_party_pct` variable for Republicans and Democrats. (Hint: there are a few ways to do this; one is to use the separate data frames for each party from 1.2 and then use `.hist()` on that.)**

# %%
#Code for 1.3
senator_D['votes_with_party_pct'].hist()
# Out:
# <AxesSubplot:>

# %%
senator_R['votes_with_party_pct'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Part 2: Correlation
# Our discussion of healthcare so far had a bit of a US-centric focus. Let's take a more *comparative* approach, by checking if countries that spend more on health care tend to have healthier citizens. In the following example, will look at the correlation between health care spending as a proportion of GDP and life expectancy in OECD countries.
#
# The variable we will use for health care spending is the amount spent as a proportion of the total economic output (GDP) in 2015.
#
# The variable we will used to measure the health of citizens is their life expectancy, or how long  the typical person lives, also in 2015.
#
# Since both variables are continuous, one natural way to measure the strength of the relationship is with the *correlation*: the degree to which one of the variable's change in value coincides with a change in value in the other variable.

# %% [markdown]
# First, we need to load in the data set from a CSV. Just to see another example of how to load data, this one is stored on my website.

# %%
healthspend = pd.read_csv("https://anthlittle.github.io/classdata/outspend2015.csv")
healthspend
# Out:
#             Country  Year  Expectancy  Spending
# 0         Australia  2015        84.5     9.321
# 1           Austria  2015        83.7    10.343
# 2           Belgium  2015        83.4    10.106
# 3            Canada  2015        83.9    10.377
# 4             Chile  2015        82.7     8.022
# 5    Czech Republic  2015        81.6     7.243
# 6           Denmark  2015        82.7    10.274
# 7           Estonia  2015        82.2     6.482
# 8           Finland  2015        84.4     9.743
# 9            France  2015        85.5    11.501
# 10          Germany  2015        83.1    11.079
# 11           Greece  2015        83.7     8.194
# 12          Hungary  2015        79.0     7.121
# 13          Iceland  2015        83.8     8.346
# 14          Ireland  2015        83.4     7.446
# 15           Israel  2015        84.1     7.375
# 16            Italy  2015        84.9     8.985
# 17            Japan  2015        87.0    10.872
# 18            Korea  2015        85.2     7.049
# 19           Latvia  2015        79.5     5.711
# 20        Lithuania  2015        79.7     6.476
# 21       Luxembourg  2015        84.7     6.226
# 22           Mexico  2015        77.7     5.756
# 23      Netherlands  2015        83.2    10.395
# 24      New Zealand  2015        83.4     9.307
# 25           Norway  2015        84.2    10.109
# 26           Poland  2015        81.6     6.343
# 27         Portugal  2015        84.3     8.972
# 28  Slovak Republic  2015        80.2     6.868
# 29         Slovenia  2015        83.9     8.485
# 30            Spain  2015        85.7     9.120
# 31           Sweden  2015        84.1    11.008
# 32      Switzerland  2015        85.1    11.894
# 33           Turkey  2015        80.7     4.139
# 34   United Kingdom  2015        82.8     9.793
# 35    United States  2015        81.1    16.816

# %% [markdown]
# One way to make a scatter plot is with the `.scatterplot` function in the seaborn library.
# First we will import seaborn and some other libraries we will need.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import numpy as np
from ipywidgets import *
from scipy import stats
from IPython.display import display, Markdown

# %% [markdown]
# The first argument of the `sns.scatterplot` function is the x axis variable, the second is the y axis variable, and the third tells us that both of these are in our `healthspend` data frame.

# %%
sns.scatterplot(x='Spending', y='Expectancy', data=healthspend)
# Out:
# <AxesSubplot:xlabel='Spending', ylabel='Expectancy'>

# %% [markdown]
# **Question 2.1. Create a scatterplot with life expectancy on the x axis and spending on the y axis.**

# %%
# Code for 2.1
sns.scatterplot(x='Expectancy', y='Spending', data=healthspend)
# Out:
# <AxesSubplot:xlabel='Expectancy', ylabel='Spending'>

# %% [markdown]
# To get a sense of which "quadrant" each country is in, we can make a vertical line at the average spending and a horizontal line at the average life expectancy.

# %%
sns.scatterplot(x='Spending', y='Expectancy', data=healthspend)
plt.axvline(np.mean(healthspend['Spending']))
plt.axhline(np.mean(healthspend['Expectancy']))

# %% [markdown]
# One way to compute the correlation is with the `.pearsonr` function in the stats library. The first number returned is the correlation. The second relates to a hypothesis test which we won't discuss, so you can ignore it.

# %%
stats.pearsonr(healthspend['Spending'], healthspend['Expectancy'])
# Out:
# (0.42008562489192164, 0.010747636192180629)

# %% [markdown]
# The correlation is postive at .42.

# %% [markdown]
# **Question 2.2. Create a dataframe called `spend_noUS` which drops out the United States. (Hint: a logical condition which says that a variable 'var' in a dataframe df is not equal to X is `df['var'] != X`) Compute the correlation between health care spending and life expectancy for this set of countries Does it go up or down? Why?**

# %%
# Code for 2.2
spend_noUS = healthspend[healthspend['Country']!="United States"]
stats.pearsonr(spend_noUS['Spending'], spend_noUS['Expectancy'])
# Out:
# (0.64613178395888193, 2.7586432526813288e-05)

# %% [markdown]
# The correlation is now higher by about .2. This is because the US is a big outlier with high spending and low expectancy, and so the relationship looks stronger when we don't include it.

# %% [markdown]
# ## Part 3: Bivariate Regression
# When we have two continuous variables (one dependent, one independent), we can use *bivariate regression* to determine how closely the two are related.

# %% [markdown]
# Above, it appears that as spending increases (as we move further to the right on the x-axis), Expectancy also increases. If we wanted to use this data to make predictions (perhaps for other countries, or the same countries in the future), we could use a linear model to represent the variables' relationship. Below, you can change the slope and intercept of the line to best fit the data:

# %%
def draw_line(slope, intercept):
    #The Linear Model
    #    def f(x):
    #    return intercept*(slope-1)/30*x +intercept
    def f(x):
        return intercept + slope*x
    x = np.arange(4,16)
    y_pred = f(x)
    points = (zip(spend_noUS.Spending, spend_noUS.Expectancy))
    #The line
    sns.scatterplot(x='Spending', y='Expectancy', data=spend_noUS)
    plt.plot(x,y_pred)
    #The actual data 
    plt.xlabel('Spending')
    plt.ylabel('expectancy')
    display(Markdown(rf'$\hat y$= {slope}$X$ + {intercept}:'))

# %%
draw_line(slope=.3, intercept=75)
# Out:
# $\hat y$= 0.3$X$ + 75:

# %% [markdown]
# That line is definitely too low to be making good predictions. Let's try to do better.

# %% [markdown]
# **Question 3.1. Find a line that you think fits the data best by playing around with the slope and intercept arguments in the `draw_line` function.**

# %%
# Code for 3.1
draw_line(slope=.5, intercept=79)
# Out:
# $\hat y$= 0.5$X$ + 79:

# %% [markdown]
# When we are evaulating how "good" a line is, we must address the *residuals*, the difference between the real and predicted values of y: $e_i = Y_i - \hat{Y_i}$. Because every real y value has an associated residual, we need some way to aggregate the residuals if we are to measure the overall quality of a line.
#
# The main measurement of aggregate error is the the *sum of squared errors*, calculated by adding the squared values of the residuals:
# $$\sum_{i=1}^n e_i^2 = \sum_{i=1}^n (Y_i-\hat{Y_i})^2$$
#
# We want the line that results in the smallest value (indicating that the total difference between the predicted and actual values is small). Below, try to minimize either the absolute or squared loss:

# %%
from IPython.display import display, Markdown

# %%
def draw_line(slope, intercept):
    #The Linear Model
    def f(x):
        return intercept + slope*x
    x = np.arange(4,16)
    y_pred = f(x)
    display(Markdown(rf'$\hat y$= {slope}$X$ + {intercept}:'))
    #The line
    plt.plot(x,y_pred)
    #The Data
    sns.scatterplot(x='Spending', y='Expectancy', data=spend_noUS)
    #Print the loss
    print("Square Residual Sum:", sum([(y-f(x))**2 for x,y in zip(spend_noUS.Spending, spend_noUS.Expectancy)]))

# %%
draw_line(slope=.3, intercept = 78)
# Out:
# $\hat y$= 0.3$X$ + 78:
# Square Residual Sum: 331.19011750999994

# %% [markdown]
# **Question 3.2. Use the new version of `draw_line` to check the sum of squared residuals for the slope and intercept you found in 3.1. Then tweak the slope and intercept to find a best fit line which leads to a lower residual sum of scquares.**

# %%
# Code for 3.2
draw_line(slope=.5, intercept=79)
# Out:
# $\hat y$= 0.5$X$ + 79:
# Square Residual Sum: 88.89345975

# %%
draw_line(slope=.7, intercept=77)
# Out:
# $\hat y$= 0.7$X$ + 77:
# Square Residual Sum: 84.04321311000007

# %% [markdown]
# Now let's us a theoretical formula to find the line that minimizes the squared residuals. To find the slope ($b$) and y-intercept ($a$), recall the following equations are used:
# $$b = \frac{\sum_{i=1}^n (X_i - \overline{X})(Y_i - \overline{Y})}{\sum_{i=1}^n (X_i - \overline{X})^2}$$
# $$a = \overline{Y}-b\overline{X}$$
# *Reminder*: $\overline{X}$ represents the mean value of X.

# %% [markdown]
# The main way we will find this least squares line (and do later work with regression) is using the "statsmodelsformula" library, which we imported as `smf`. A nice thing about this library  is that it mimics the syntax of R, so if you end up using that language in another class or setting you will be able to translate pretty quickly.
#
# There are two steps to getting regression output. First, we *fit a model*, with the following syntax:
#
# `name = smf.ols('DV ~ IV', data=df).fit()`
#
# We can pick whatever we want for name. For DV, put the column name of the dependent variable, and for IV put the column name of the independent variable. For df, put the name of the data frame.
#
# Next we run a separate function which tells us to summarize the fitted model, with:
#
# `name.summary()`
#
# For example, this creates the best fit line for predicting life expectancy from spending, excluding the US:

# %%
spend_ols = smf.ols('Expectancy ~ Spending', data=spend_noUS).fit()
spend_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Expectancy   R-squared:                       0.417
# Model:                            OLS   Adj. R-squared:                  0.400
# Method:                 Least Squares   F-statistic:                     23.65
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):           2.76e-05
# Time:                        10:25:16   Log-Likelihood:                -64.880
# No. Observations:                  35   AIC:                             133.8
# Df Residuals:                      33   BIC:                             136.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     77.2226      1.244     62.056      0.000      74.691      79.754
# Spending       0.6883      0.142      4.863      0.000       0.400       0.976
# ==============================================================================
# Omnibus:                        0.066   Durbin-Watson:                   2.184
# Prob(Omnibus):                  0.967   Jarque-Bera (JB):                0.046
# Skew:                          -0.036   Prob(JB):                        0.977
# Kurtosis:                       2.838   Cond. No.                         41.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# There is lots of output here, most of which we haven't covered yet/won't cover at all. For now, the key thing to notice are the two valus in the "coef" column in the second table. The first one gives the intercept, and the second the slope on the best fit line. How close are these to your answer from 3.2?

# %% [markdown]
# **Question 3.3. Find the best fit line for predicting life expectancy from health care spending using the data which also includes the US. How does the slope change, and why?**

# %%
# Code for 3.3
spend_ols_US = smf.ols('Expectancy ~ Spending', data=healthspend).fit()
spend_ols_US.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Expectancy   R-squared:                       0.176
# Model:                            OLS   Adj. R-squared:                  0.152
# Method:                 Least Squares   F-statistic:                     7.286
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):             0.0107
# Time:                        10:25:50   Log-Likelihood:                -72.956
# No. Observations:                  36   AIC:                             149.9
# Df Residuals:                      34   BIC:                             153.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     79.8330      1.242     64.294      0.000      77.310      82.356
# Spending       0.3678      0.136      2.699      0.011       0.091       0.645
# ==============================================================================
# Omnibus:                        5.311   Durbin-Watson:                   1.822
# Prob(Omnibus):                  0.070   Jarque-Bera (JB):                3.992
# Skew:                          -0.779   Prob(JB):                        0.136
# Kurtosis:                       3.482   Cond. No.                         36.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# The slope goes down a lot because when the US is in the sample the relationship is weaker on average.

# %% [markdown]
# Finally, let's return to the data about gun ownership and gun deaths from week 1. In the table we import here the estimated rate of gun ownership is in the "HFR" column and the deaths per 100,000 residents is  in the "Deathrate" column.

# %%
gunstate = pd.read_csv("data/gunstate2016.csv")
gunstate.loc[np.arange(5)]
# Out:
#    Unnamed: 0  Year       State    HFR  Abbrev Code  Deathrate  Deaths
# 0           3  2016     Alabama  0.528    Ala.   AL       21.5    1046
# 1           7  2016      Alaska  0.572  Alaska   AK       23.3     177
# 2          11  2016     Arizona  0.360   Ariz.   AZ       15.2    1094
# 3          15  2016    Arkansas  0.518    Ark.   AR       17.8     541
# 4          19  2016  California  0.163  Calif.   CA        7.9    3184

# %% [markdown]
# **Question 3.4. . Make a scatter plot with the gun ownership on the x axis and the death rate on the y axis. Then find the best fit line for this relationship using `smf.ols`. Interpret the slope on gun ownership (Hint: it might make more sense to describe the effect of a 10% or .1 increase in gun ownership).**

# %%
# Code for 3.4
sns.scatterplot(x='HFR', y='Deathrate', data=gunstate)
# Out:
# <AxesSubplot:xlabel='HFR', ylabel='Deathrate'>

# %%
gundeaths = smf.ols('Deathrate ~ HFR', data=gunstate).fit()
gundeaths.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Deathrate   R-squared:                       0.578
# Model:                            OLS   Adj. R-squared:                  0.569
# Method:                 Least Squares   F-statistic:                     65.79
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):           1.50e-10
# Time:                        10:27:31   Log-Likelihood:                -128.59
# No. Observations:                  50   AIC:                             261.2
# Df Residuals:                      48   BIC:                             265.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.8547      1.338      2.134      0.038       0.164       5.545
# HFR           25.6935      3.168      8.111      0.000      19.324      32.063
# ==============================================================================
# Omnibus:                        1.485   Durbin-Watson:                   2.407
# Prob(Omnibus):                  0.476   Jarque-Bera (JB):                1.080
# Skew:                           0.012   Prob(JB):                        0.583
# Kurtosis:                       2.280   Cond. No.                         8.04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# The slope on HFR is about 25. This means that if gun ownership goes up by .1, the deaths per 100,000 citizens is predicted to goup by about 2.5.

# %% [markdown]
# **Question 3.5. Recall in week 1 we discussed how some theories other than gun ownership causing gun deaths could (partially) explain this relationship. Recast that argument in the language we developed over the past few weeks. In other words, why might the slope in this regression not be a good estimate of the causal effect of gun ownership on gun deaths?**

# %% [markdown]
# There might be selection bias in this estimate because the places that have a higher gun ownership rate might have higher gun deaths for other reasons. This could be due to a confounding variable like a general violent culture, or reverse causation if people are more apt to buy guns in more dangerous places.
