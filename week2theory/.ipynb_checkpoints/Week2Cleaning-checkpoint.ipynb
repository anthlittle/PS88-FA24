# %%
# Importing libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Higher res graphs
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %% [markdown]
# # Slide Graphs

# %%
life = pd.read_csv("data/life-expectancy-vs-gdp-per-capita.csv")
life2018 = life[life['Year']==2018]
life2018
sns.scatterplot(x='GDP per capita', y='Life expectancy at birth (historical)', data=life2018)
plt.ylabel('Life expectancy at birth')
# Out:
# Text(0, 0.5, 'Life expectancy at birth')

# %%
happy = pd.read_csv("data/gdp-vs-happiness.csv")
happy2018 = happy[happy['Year']==2018]
sns.scatterplot(x='GDP per capita', y='Life satisfaction', data=happy2018)
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='Life satisfaction'>

# %%
pv = pd.read_stata("data/presvote.dta")
pv
# Out:
#        year   incvote     RDIy  RDIyrgrowth  RDIg_term  RDIg_termmean  termed  \
# 0    1789.0       NaN      NaN          NaN        NaN            NaN     NaN
# 1    1790.0       NaN      NaN          NaN        NaN            NaN     NaN
# 2    1791.0       NaN      NaN          NaN        NaN            NaN     NaN
# 3    1792.0       NaN      NaN          NaN        NaN            NaN     NaN
# 4    1793.0       NaN      NaN          NaN        NaN            NaN     NaN
# ..      ...       ...      ...          ...        ...            ...     ...
# 227  2016.0  0.511133  42207.0     1.246872   5.912127       1.478032     1.0
# 228  2017.0       NaN  43234.0     2.404114        NaN            NaN     NaN
# 229  2018.0       NaN  44553.0     3.005227        NaN            NaN     NaN
# 230  2019.0       NaN  45301.0     1.664962        NaN            NaN     NaN
# 231  2020.0  0.477299  47755.0     5.275466  12.349769       3.087442     NaN
#
# ...

# %%
pv = pv[pv['incvote'].notnull()]
pv
# Out:
#        year   incvote     RDIy  RDIyrgrowth  RDIg_term  RDIg_termmean  termed  \
# 39   1828.0  0.438058      NaN          NaN        NaN            NaN     NaN
# 43   1832.0  0.591728      NaN          NaN        NaN            NaN     NaN
# 47   1836.0  0.508333      NaN          NaN        NaN            NaN     NaN
# 51   1840.0  0.469457      NaN          NaN        NaN            NaN     NaN
# 55   1844.0  0.492519      NaN          NaN        NaN            NaN     NaN
# 59   1848.0  0.473319      NaN          NaN        NaN            NaN     NaN
# 63   1852.0  0.463171      NaN          NaN        NaN            NaN     NaN
# 67   1856.0  0.577669      NaN          NaN        NaN            NaN     NaN
# 71   1860.0  0.544248      NaN          NaN        NaN            NaN     NaN
# 75   1864.0  0.550305      NaN          NaN        NaN            NaN     NaN
# 79   1868.0  0.473201      NaN          NaN        NaN            NaN     NaN
# ...

# %%
pv=pv[pv['year']>=1940]

# %%
sns.scatterplot(x='gdpchange', y='incvote', data=pv)
plt.xlabel('GDP Growth')
plt.ylabel('Incumbent Vote Share')
# Out:
# Text(0, 0.5, 'Incumbent Vote Share')

# %%
sns.scatterplot(x='gdpchange', y='incvote', data=pv)
plt.xlabel('GDP Growth')
plt.ylabel('Incumbent Vote Share')
plt.text(pv['incvote'])

# %%
sns.scatterplot(x='RDIyrgrowth', y='incvote', data=pv)
sns.scatterplot(x='RDIyrgrowth', y='incvote', data=pv[pv['year']==2016])
sns.scatterplot(x='RDIyrgrowth', y='incvote', data=pv[pv['year']==2020])
# Out:
# <AxesSubplot:xlabel='RDIyrgrowth', ylabel='incvote'>

# %% [markdown]
# # Cleaning for Lab

# %%
sen = pd.read_csv("data/1976-2020-senate.csv", encoding= 'unicode_escape')
sen
# Out:
#       year    state state_po  state_fips  state_cen  state_ic     office  \
# 0     1976  ARIZONA       AZ           4         86        61  US SENATE
# 1     1976  ARIZONA       AZ           4         86        61  US SENATE
# 2     1976  ARIZONA       AZ           4         86        61  US SENATE
# 3     1976  ARIZONA       AZ           4         86        61  US SENATE
# 4     1976  ARIZONA       AZ           4         86        61  US SENATE
# ...    ...      ...      ...         ...        ...       ...        ...
# 3624  2020  WYOMING       WY          56         83        68  US SENATE
# 3625  2021  GEORGIA       GA          13         58        44  US SENATE
# 3626  2021  GEORGIA       GA          13         58        44  US SENATE
# 3627  2021  GEORGIA       GA          13         58        44  US SENATE
# 3628  2021  GEORGIA       GA          13         58        44  US SENATE
#
#        district   stage  special            candidate party_detailed  writein  \
# ...
